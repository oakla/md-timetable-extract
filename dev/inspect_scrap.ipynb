# %%
import pandas as pd
from pathlib import Path
from md_timetable_extract import extract, post_processing, structs, conf

# %%
df = extract.extract_calendar_page_view_as_df(
    conf.INPUT_TIMETABLE, 
    "3", 
    line_scale=60)

# %%
df
# Out:
#                                                    0   \
# 0   Weekly Timetable - IMED4113 Integrated Medical...
# 1                      Week 3 - Musculoskeletal Block
# 2                                                Time
# 3         ONLINE (allocated \nby teaching \nsequence)
# 4         ONLINE (allocated \nby teaching \nsequence)
# 5         ONLINE (allocated \nby teaching \nsequence)
# 6         ONLINE (allocated \nby teaching \nsequence)
# 7         ONLINE (allocated \nby teaching \nsequence)
# 8                                                8.00
# 9                                                9.00
# 10                                              10.00
# 11                                              11.00
# 12                                              12.00
# 13                                              13.00
# 14                                              14.00
# 15                                              15.00
# ...
